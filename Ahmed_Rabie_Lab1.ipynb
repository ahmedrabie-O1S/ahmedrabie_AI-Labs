# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedrabie-O1S/ahmedrabie_AI-Labs/blob/main/Ahmed_Rabie_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def travel_agent():
    print("Simple Travel Agent")

    budget = int(input("Enter your total budget in PKR (Rs): "))
    print("Trip Types: 1. Relaxing | 2. Historical | 3. Adventurous")
    pref = input("What kind of trip do you prefer? ").strip().lower()

    if budget < 50000:
        if pref == "relaxing":
            destination = "Hawke's Bay / French Beach, Karachi"
            transport = "Private Car / Taxi"
        elif pref == "historical":
            destination = "Lahore Fort & Badshahi Mosque"
            transport = "Train or Bus"
        else:
            destination = "Gorakh Hill Station"
            transport = "4x4 Jeep"

    elif budget <= 200000:
        if pref == "relaxing":
            destination = "Astola Island / Gwadar Beaches"
            transport = "Coaster / Private Vehicle"
        elif pref == "historical":
            destination = "Baku, Azerbaijan"
            transport = "Economy Flight"
        else:
            destination = "Hunza & Skardu Valleys"
            transport = "By Road / Domestic Flight"

    else:
        if pref == "relaxing":
            destination = "Maldives"
            transport = "International Flight & Speedboat"
        elif pref == "historical":
            destination = "Istanbul, Turkey"
            transport = "Direct Flight"
        else:
            destination = "Queenstown, New Zealand"
            transport = "Connecting Flight & Car Rental"

    print("\n--- Travel Recommendation ---")
    print(f"Recommended Destination : {destination}")
    print(f"Suggested Mode of Travel: {transport}")

travel_agent()
# Out:
# Simple Travel Agent
# Enter your total budget in PKR (Rs): 15000
# Trip Types: 1. Relaxing | 2. Historical | 3. Adventurous
# What kind of trip do you prefer? relaxing
#
# --- Travel Recommendation ---
# Recommended Destination : Hawke's Bay / French Beach, Karachi
# Suggested Mode of Travel: Private Car / Taxi
