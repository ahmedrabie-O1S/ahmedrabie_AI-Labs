# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedrabie-O1S/ahmedrabie_AI-Labs/blob/main/Ahmed_Rabie_Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6JtJ1UEYDCPHOG9SXAse6wckET9YFn1aMacy3fmk-w7Hg")
MODEL = "models/gemini-3.8-flash"

print("Gemini Chatbot (type 'exit' to quit)\n")

# Chat loop
while True:
    user_input = input("You: ")

    # Exit condition
    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye 👋")
        break

    # Send input to Gemini
    response = client.models.generate_content(
        model=MODEL,
        contents=user_input
    )

    # Print response
    print("Chatbot:", response.text)

# %% [markdown]
# This command will install the `pandas` library. You can replace `pandas` with the name of any other library you wish to install. It's usually good practice to run these installation commands in their own code cells.
