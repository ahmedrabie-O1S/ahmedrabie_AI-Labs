# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedrabie-O1S/ahmedrabie_AI-Labs/blob/main/Ahmed_Rabie_Lab3_8_9_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6KxOx1P2iKidu3VbJ-9fwJaIK8Y-hddQGAlFL9m7gsRlg")


MODEL = "models/gemini-3.5-flash"


def travel_agent(user_input):

    prompt = f"""
You are a professional travel agent for Pakistan tourism.

Provide a well-structured travel plan with clear headings:

1. Destination Overview
2. Budget Travel Options (Bus, Train, Flight with approx cost in PKR)
3. Places to Visit (specific locations)
4. Food Suggestions (local dishes)
5. Money-Saving Tips

Make response detailed but easy for students.

User request: {user_input}

Travel Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Travel Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# ...
# Gemini Travel Agent Started (type 'exit' to stop)
#
#
# Agent:
#  Hello and welcome! As your dedicated travel agent for Pakistan Tourism, I am thrilled to help you plan an unforgettable journey.
#
# Since you are looking for a student-friendly adventure that balances breathtaking views with affordability, I highly recommend **Hunza Valley** in Gilgit-Baltistan. It is one of the safest, most beautiful, and culturally rich destinations in Pakistan, making it perfect for student groups.
#
# Here is your detailed, budget-friendly travel plan to Hunza Valley:
#
# ---
#
# ### 1. Destination Overview: Hunza Valley
# Located in the northern part of Gilgit-Baltistan, Hunza is a mountainous valley surrounded by towering peaks like Rakaposhi and the Passu Cones. Known as the "Heaven on Earth," Hunza offers stunning turquoise lakes, ancient forts, friendly locals, and a virtually 100% literacy rate. It is incredibly safe for solo travelers, female students, and groups.
# ...

# %%
# !pip install -U google-genai
from google import genai
client = genai.Client(api_key="AQ.Ab8RN6KxOx1P2iKidu3VbJ-9fwJaIK8Y-hddQGAlFL9m7gsRlg")
MODEL = "models/gemini-3.5-flash"
def skill_advisor_agent(user_input):
    prompt = f"""
You are a professional skill advisor who helps learners figure out what skill to learn next.
Provide a well-structured recommendation with clear headings:
1. Skill Overview
2. Why This Skill Fits (based on the learner's interest, goal, and current level)
3. Learning Path (beginner to job-ready, step by step)
4. Time & Effort Estimate (roughly how long it takes, hours per week)
5. Free & Low-Cost Resources (courses, sites, or tools to start with)

Make response detailed but easy for students.

User request: {user_input}

Skill Recommendation:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Skill Advisor Agent Started (type 'exit' to stop)\n")
while True:
    user = input("You: ")
    if user.lower() == "exit":
        print("Goodbye ")
        break
    try:
        reply = skill_advisor_agent(user)
        print("\nAgent:\n", reply, "\n")
    except Exception as e:
        print("Error:", e)
# Out:
# ...
# Gemini Skill Advisor Agent Started (type 'exit' to stop)
#
# You: Hello
#
# Agent:
#  Hello! I am your skill advisor, and I'm excited to help you plan your next learning journey.
#
# Since you've just said hello, I am going to recommend one of the most versatile, high-demand, and beginner-friendly skills in the modern job market: **Data Analytics**. Whether you are in business, science, humanities, or tech, data skills are universally valuable.
#
# *If you already have a specific field in mind (like coding, design, or marketing), let me know in your next reply, and I will customize a plan just for you!*
#
# Here is your tailored recommendation for **Data Analytics**:
#
# ---
#
# ### 1. Skill Overview
# ...
